# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
modelConf = "Yolov3-tiny.cfg"
modelWeights = "Yolov3-tiny.weights"
net = cv2.dnn.readNetFromDarknet(modelConf, modelWeights)
net

# %%
l = net.getLayerNames()
print(l[:5])
len(l)

# %%
# reshaping the image according to the model requirement

inpWidth = 416
inpHeight = 416

frame = cv2.imread("D:\Data Science by SRK\Omkar Sir 10.30AM Batch\OpenCV\IMG_5749.JPG")

blob = cv2.dnn.blobFromImage()
